# %% [markdown]
# # Dataset exploration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

pd.set_option('display.max_columns', None)

# %%
filepath = './data/BeerAdvocate/'

# %%
df = pd.read_csv(filepath + 'BeerAdvocateMerged.csv')

# %%
df.sample(3)
# Out:
#                                                 beer_name  beer_id  \
# 388941                                      Crack'd Wheat    47539
# 51846   Thornbridge Hall / St. Eriks Bryggeri Imperial...   104093
# 91073                              Pacifico Cerveza Clara     2755
#
#                       brewery_name  brewery_id  \
# 388941  New Glarus Brewing Company         590
# 51846          Thornbridge Brewery       13029
# 91073    Grupo Modelo S.A. de C.V.          75
#
#                                    style    abv        date  user_name  \
# 388941                        Hefeweizen   5.95  1247565600   HopDerek
# 51846   American Double / Imperial Stout  10.00  1446462000  Hoppsbabo
# 91073             American Adjunct Lager   4.50  1153303200  Noxious26
#
#                  user_id  appearance  aroma  palate  taste  overall  rating  \
# 388941   hopderek.110806        4.00   4.50     4.0    4.0     4.50    4.22
# 51846   hoppsbabo.657288        4.25   4.25     4.0    4.0     3.75    4.03
# 91073    noxious26.22115        2.50   2.00     2.5    2.5     3.00    2.48
#
#                                                      text  user_nbr_ratings  \
# 388941  Thanks to MasterSki for this trade.Pours a sli...               632
# 51846   Mine's a 2013 bottle.A: Gloopy black with a be...               418
# 91073   355ml bottle poured in a pilsener glass.Clear,...               451
#
#         user_nbr_reviews   user_joined                user_location  \
# 388941               632  1.165576e+09  United States, Pennsylvania
# 51846                411  1.327835e+09                      England
# 91073                422  1.117793e+09                       Canada
#
#         beer_nbr_ratings  beer_nbr_reviews  beer_ba_score  beer_avg  \
# 388941             320.0             263.0           91.0      4.14
# 51846               18.0               7.0           85.0      3.93
# 91073             1962.0             539.0           63.0      2.66
#
#                 brewery_location  brewery_nbr_beers
# 388941  United States, Wisconsin               92.0
# 51846                    England              105.0
# 91073                     Mexico               21.0

# %% [markdown]
# # Data filtering and enrichment

# %%
# Create 3 different columns according to the text review, "bottle", "can", "draft"

bottle = ['bottle', 'bottled', 'bottles']
can = ['can', 'canned', 'cans']
draft = ['draft', 'draught', 'tap', 'taps']
# Create different columns if review text contains the word
df['bottle'] = df['text'].apply(lambda x: any(ele in x.lower() for ele in bottle))
df['can'] = df['text'].apply(lambda x: any(ele in x.lower() for ele in can))
df['draft'] = df['text'].apply(lambda x: any(ele in x.lower() for ele in draft))

# %%
# remove every row where columns bottle, can and draft are all False
df = df[df[['bottle', 'can', 'draft']].any(axis=1)]
display(df.sample(3))
print('We have {} valid reviews'.format(df.shape[0]))
# Out:
#                                        beer_name  beer_id  \
# 1120852                              Bittersweet   182398
# 437199       W-n-B Coffee Oatmeal Imperial Stout    21950
# 1836227  Moose & Squirrel Russian Imperial Stout    40732
#
#                               brewery_name  brewery_id  \
# 1120852          Left Hand Brewing Company         418
# 437199               Terrapin Beer Company        2372
# 1836227  Laurelwood Public House & Brewery       16289
#
#                                     style  abv        date    user_name  \
# 1120852                Milk / Sweet Stout  8.9  1448103600     Beaver13
# 437199   American Double / Imperial Stout  9.4  1263726000  Freethyhops
# 1836227            Russian Imperial Stout  8.0  1478084400    arizcards
#
#                     user_id  appearance  aroma  palate  taste  overall  \
# 1120852       beaver13.3586        3.50    3.0     2.5    3.0      3.0
# 437199   freethyhops.317808        4.50    4.0     4.5    4.5      4.0
# 1836227      arizcards.2240        4.25    4.0     4.0    4.0      4.0
#
#          rating                                               text  \
# 1120852    2.98  22 oz bottle.  Pours dark brown with a small c...
# 437199     4.28  09 Vintage 12oz bottleA- pours pitch black. a ...
# 1836227    4.02  Picked up a 22 oz bottle from the Belmont Stat...
#
#          user_nbr_ratings  user_nbr_reviews   user_joined  \
# 1120852              1793              1762  1.068376e+09
# 437199                145               141  1.239185e+09
# 1836227              1997              1971  1.055326e+09
#
#                    user_location  beer_nbr_ratings  beer_nbr_reviews  \
# 1120852  United States, Colorado             289.0              72.0
# 437199    United States, Montana            3946.0            1308.0
# 1836227   United States, Arizona              50.0              21.0
#
#          beer_ba_score  beer_avg         brewery_location  brewery_nbr_beers  \
# 1120852           91.0      4.11  United States, Colorado              115.0
# 437199            94.0      4.25   United States, Georgia              183.0
# 1836227           84.0      3.69    United States, Oregon              151.0
#
#          bottle    can  draft
# 1120852    True  False  False
# 437199     True  False  False
# 1836227    True  False  False
# We have 1197840 valid reviews

# %%
# remove every row with more than 1 true
df = df[df[['bottle', 'can', 'draft']].sum(axis=1) == 1]
display(df.sample(3))
print('We have {} valid reviews'.format(df.shape[0]))
# Out:
#                    beer_name  beer_id          brewery_name  brewery_id  \
# 994864   Evil Twin Bozo Beer   107284     Evil Twin Brewing       24300
# 1666855    Bell's Batch 9000    55732  Bell's Brewery, Inc.         287
# 949835    Brooklyn Brown Ale      146      Brooklyn Brewery          45
#
#                                     style   abv        date  user_name  \
# 994864   American Double / Imperial Stout  17.2  1455534000   larryi86
# 1666855               American Strong Ale  12.5  1276336800  ArrogantB
# 949835                 American Brown Ale   5.6  1301306400  eporter66
#
#                   user_id  appearance  aroma  palate  taste  overall  rating  \
# 994864    larryi86.445106         4.0    3.5     4.5    4.5      4.0    4.13
# 1666855   arrogantb.82886         4.0    3.0     3.5    3.0      3.0    3.11
# 949835   eporter66.267326         2.5    3.5     4.0    2.5      2.5    2.89
#
#                                                       text  user_nbr_ratings  \
# 994864   22 oz bottle poured into a tekuA- Black with a...              1311
# 1666855  12oz bottle thanks to zestar (?). I shared thi...              2341
# 949835   12oz Pint glass - on draftA - No head at all w...                92
#
#          user_nbr_reviews   user_joined            user_location  \
# 994864               1232  1.270375e+09  United States, Delaware
# 1666855              2334  1.149847e+09  United States, Colorado
# 949835                 92  1.226920e+09  United States, New York
#
#          beer_nbr_ratings  beer_nbr_reviews  beer_ba_score  beer_avg  \
# 994864              256.0              40.0           93.0      4.22
# 1666855             911.0             539.0           89.0      4.00
# 949835             2361.0             957.0           83.0      3.67
#
#                 brewery_location  brewery_nbr_beers  bottle    can  draft
# 994864   United States, New York              248.0    True  False  False
# 1666855  United States, Michigan              312.0    True  False  False
# 949835   United States, New York              181.0   False  False   True
# We have 939088 valid reviews

# %%
#create a new column with the serving type
df['serving_type'] = df[['bottle', 'can', 'draft']].idxmax(axis=1)

# drop the columns bottle, can and draft
df.drop(['bottle', 'can', 'draft'], axis=1, inplace=True)

df.sample(3)
# Out:
#                          beer_name  beer_id  \
# 86068                          Sol     2803
# 1219315                 Hefeweizen     2249
# 1559834  Town Beach India Pale Ale   186871
#
#                                           brewery_name  brewery_id  \
# 86068    Cervecería Cuauhtémoc Moctezuma, S.A. de C.V.          57
# 1219315                             Flying Dog Brewery          68
# 1559834                       Narragansett Brewing Co.         213
#
#                           style  abv        date    user_name  \
# 86068    American Adjunct Lager  4.5  1386500400  WillWillows
# 1219315              Hefeweizen  4.7  1119520800        AlexJ
# 1559834            American IPA  4.7  1493460000   kojevergas
#
#                     user_id  appearance  aroma  palate  taste  overall  \
# 86068    willwillows.716411         3.0   3.00    3.00   3.00     3.00
# 1219315          alexj.8158         3.0   3.00    3.00   3.50     3.50
# 1559834   kojevergas.492136         2.5   1.75    1.75   1.75     1.75
#
#          rating                                               text  \
# 86068       3.0  I drank several of these ice cold from the coo...
# 1219315     3.3  Hazy peachy pale yellow with fluffy white head...
# 1559834     1.8  (As &quot;Town Beach Day Pass IPA&quot;). Purc...
#
#          user_nbr_ratings  user_nbr_reviews   user_joined  \
# 86068                 101                43  1.359803e+09
# 1219315               882               882  1.093342e+09
# 1559834              6532              5016  1.281866e+09
#
#                          user_location  beer_nbr_ratings  beer_nbr_reviews  \
# 86068              United States, Ohio            1406.0             398.0
# 1219315  United States, North Carolina            1607.0             723.0
# 1559834        United States, New York              83.0              37.0
#
#          beer_ba_score  beer_avg             brewery_location  \
# 86068             60.0      2.50                       Mexico
# 1219315           80.0      3.52      United States, Maryland
# 1559834           82.0      3.56  United States, Rhode Island
#
#          brewery_nbr_beers serving_type
# 86068                 55.0          can
# 1219315              201.0          can
# 1559834               33.0          can

# %%
# print the number of reviews for each serving type
df['serving_type'].value_counts(normalize=False)
# Out:
# serving_type
# bottle    479777
# can       344842
# draft     114469
# Name: count, dtype: int64

# %%
# compute the number of valid reviews per user
df['user_nbr_reviews_computed'] = df.groupby('user_id')['user_id'].transform('count')

# compute the number of valid reviews per beer
df['beer_nbr_reviews_computed'] = df.groupby('beer_id')['beer_id'].transform('count')

# compute the avg rating per beer
df['beer_avg_computed'] = df.groupby('beer_id')['rating'].transform('mean')

df.sample(3)
# Out:
#                                        beer_name  beer_id  \
# 1789013  Special Herbs (Sole Composition Series)    66768
# 725321                 Stone 8th Anniversary Ale    19186
# 1756860                      New Holland Envious    57401
#
#                         brewery_name  brewery_id  \
# 1789013      Upright Brewing Company       19866
# 725321                 Stone Brewing         147
# 1756860  New Holland Brewing Company         335
#
#                                        style  abv        date     user_name  \
# 1789013  Scottish Gruit / Ancient Herbed Ale  6.0  1334916000      raveskdr
# 725321                    American Brown Ale  7.8  1328526000      FosterJM
# 1756860               Fruit / Vegetable Beer  7.5  1272621600  danielharper
#
#                    user_id  appearance  aroma  palate  taste  overall  rating  \
# 1789013    raveskdr.380022         4.0    4.0     4.5    5.0      4.5    4.55
# 725321     fosterjm.393822         3.5    3.5     3.5    4.0      3.5    3.70
# 1756860  danielharper.9186         4.0    4.5     4.0    4.5      4.0    4.32
#
#                                                       text  user_nbr_ratings  \
# 1789013  Bottle 132 of 166. Poured into a Bruery glass....               127
# 725321   1095th Review on BADraft to 4oz TasterWinterSt...              1829
# 1756860  Pours deep ruby red with a thick brown head th...               439
#
#          user_nbr_reviews   user_joined              user_location  \
# 1789013                69  1.255169e+09    United States, Virginia
# 725321               1828  1.258369e+09  United States, California
# 1756860               439  1.097143e+09    United States, Michigan
#
#          beer_nbr_ratings  beer_nbr_reviews  beer_ba_score  beer_avg  \
# 1789013              31.0              18.0           90.0      4.41
# 725321              264.0             231.0           89.0      3.99
# 1756860             263.0             114.0           76.0      3.26
#
#                   brewery_location  brewery_nbr_beers serving_type  \
# 1789013      United States, Oregon              200.0       bottle
# 725321   United States, California              671.0        draft
# 1756860    United States, Michigan              225.0          can
#
#          user_nbr_reviews_computed  beer_nbr_reviews_computed  \
# 1789013                         30                          9
# 725321                        1153                         99
# 1756860                        170                         50
#
#          beer_avg_computed
# 1789013           4.506667
# 725321            4.023232
# 1756860           3.213400

# %%
plt.figure(figsize=(15, 5))

# group the reviews by beer_id and show a histogram of the number of reviews computed
plt.subplot(1, 2, 1)
df.groupby('beer_id')['beer_nbr_reviews_computed'].mean().hist(bins=100, log=True)
plt.xlabel('Number of reviews per beer')
plt.ylabel('Count')

# group the reviews by user_id and show a histogram of the number of reviews computed
plt.subplot(1, 2, 2)
df.groupby('user_id')['user_nbr_reviews_computed'].mean().hist(bins=100, figsize=(15, 5), log=True)
plt.xlabel('Number of reviews per user')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
#Filtering to remove users and beers with less reviews

min_nbr_reviews_per_user = 10
min_nbr_reviews_per_beer = 20

len0 = df.shape[0]

# remove every row where the number of reviews per user is less than min_nbr_reviews_per_user
df_filter = df[df['user_nbr_reviews_computed'] >= min_nbr_reviews_per_user]

# remove every row where the number of reviews per beer is less than min_nbr_reviews_per_beer
df_filter_full = df_filter[df_filter['beer_nbr_reviews_computed'] >= min_nbr_reviews_per_beer]

print('We removed {} rows, leaving us with {} %% of the original dataset'.format(len0 - df_filter_full.shape[0], round(df_filter_full.shape[0] / len0 * 100, 2)))
print('We have {} valid reviews'.format(df_filter_full.shape[0]))

# print the number of reviews for each serving type
df_filter_full['serving_type'].value_counts(normalize=False)
# Out:
# We removed 259148 rows, leaving us with 72.4 %% of the original dataset
# We have 679940 valid reviews
# serving_type
# bottle    368770
# can       245706
# draft      65464
# Name: count, dtype: int64

# %%
from textstat import flesch_reading_ease, flesch_kincaid_grade, gunning_fog, smog_index, automated_readability_index, coleman_liau_index, linsear_write_formula, dale_chall_readability_score, text_standard

# %%
df_sample = df_filter_full.sample(n=1000, random_state=46)

# %%
df_sample['readability_score'] = df_sample['text'].apply(lambda x: flesch_reading_ease(x) if isinstance(x, str) else None)
df_sample['readability_score'].hist(bins=100, figsize=(15, 5), log=True)
# Out:
# <Axes: >

# %%
# printing some reviews based on readability score

df_sample[df_sample['readability_score'] < 20]['text'].count()

# for row in df_sample[df_sample['readability_score'] > 96]['text']:
#     print(row)
#     print('----------------------')
# Out:
# 10

# %% [markdown]
# # Visualization

# %%
df = df_filter_full.copy()

# %%
# print some reviews for each serving type
print('Reviews with bottle:\n')
for text in df[df['serving_type'] == 'bottle']['text'].sample(3):
    print(text)
    print('----------------------')
print('Reviews with can:\n')
for text in df[df['serving_type'] == 'can']['text'].sample(3):
    print(text)
    print('----------------------')
print('Reviews with draft:\n')
for text in df[df['serving_type'] == 'draft']['text'].sample(3):
    print(text)
    print('----------------------')

# %%
# print the average value of the rating for each serving type
comp_str = 'rating'
print('Average ' + comp_str + ' for bottle: ', round(df[df['serving_type'] == 'bottle'][comp_str].mean(), 3))
print('Average ' + comp_str + ' for can: ', round(df[df['serving_type'] == 'can'][comp_str].mean(), 3))
print('Average ' + comp_str + ' for draft: ', round(df[df['serving_type'] == 'draft'][comp_str].mean(), 3))

# %%
# show boxplot of ratings for bottle, can and draft
plt.figure(figsize=(10, 6))
plt.subplot(121)
sns.boxplot(data=df, hue='serving_type', y='rating')
plt.subplot(122)
sns.histplot(data=df, hue='serving_type', x='rating', kde=True, bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistical Analysis

# %%
def do_ttest(type1, type2, category):
    ttest = ttest_ind(df[df['serving_type'] == type1][category],df[df['serving_type'] == type2][category])
    if ttest[1] > 0.05:
        print('The p-value is high (' + str(ttest[1]) + '), so we cannot reject the null hypothesis that the two samples have the same average')
    else:
        print('The p-value is very low (' + str(ttest[1]) + '), so we can reject the null hypothesis that the two samples have the same average')

# %%
for i in range(9, 15):
    print('T-test between can and draft for column ' + df.columns[i] + ':')
    do_ttest('can', 'draft', df.columns[i])
    print('----------------------')
