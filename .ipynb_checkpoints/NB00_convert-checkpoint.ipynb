# %%
import pandas as pd
from tqdm import tqdm
import io

# %%
#Convert txt file to csv file

# Define the file path
file_path = '/data/BeerAdvocate/reviews.txt'

# Get the total number of lines in the file
with io.open(file_path, 'r', encoding='utf-8') as f:
    total_lines = sum(1 for _ in f)
print(f'Total number of lines: {total_lines}')

# Initialize an empty dictionary to store the data
data_dict = {}
current_key = None

# Use tqdm to visualize progress
with io.open(file_path, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in tqdm(lines, total=total_lines, desc='Processing Lines'):
        line = line.strip()
        if line:  # Skip empty lines
            key, value = line.split(':', 1)
            data_dict.setdefault(key.strip(), []).append(value.strip())
            current_key = key

print('Finished processing lines.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/annevaleriepreto/Documents/EPFL/MA-3/ADA/ada-2023-project-beeradaventure46/NB00_convert.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/Users/annevaleriepreto/Documents/EPFL/MA-3/ADA/ada-2023-project-beeradaventure46/NB00_convert.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> file_path = '/data/BeerAdvocate/reviews.txt'
#       <a href='vscode-notebook-cell:/Users/annevaleriepreto/Documents/EPFL/MA-3/ADA/ada-2023-project-beeradaventure46/NB00_convert.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> # Get the total number of lines in the file
# ----> <a href='vscode-notebook-cell:/Users/annevaleriepreto/Documents/EPFL/MA-3/ADA/ada-2023-project-beeradaventure46/NB00_convert.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> with io.open(file_path, 'r', encoding='utf-8') as f:
# ...

# %%
# Create a DataFrame from the dictionary
ratings_with_text_rb = pd.DataFrame(data_dict)

# %%
ratings_with_text_rb.tail(60)
# Out:
#                    beer_name beer_id              brewery_name brewery_id  \
# 1020539      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020540      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020541      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020542      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020543      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020544      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020545      Tawandang Lager   16787  Tawandang German Brewery       2866
# 1020546     Tawandang Weizen   16786  Tawandang German Brewery       2866
# 1020547     Tawandang Weizen   16786  Tawandang German Brewery       2866
# 1020548     Tawandang Weizen   16786  Tawandang German Brewery       2866
# 1020549     Tawandang Weizen   16786  Tawandang German Brewery       2866
# 1020550     Tawandang Weizen   16786  Tawandang German Brewery       2866
# ...

# %%
# export the df to csv
# ratings_with_text_rb.to_csv('data/matched_beer_data/ratings_with_text_rb.csv', index=False)

# %%
# read only few lines from a txt file

# import itertools

# # Define the file path and the starting line number
# file_path = 'data/RateBeer/reviews.txt'
# start_line_number = 19_000_000
# lines_to_read = 100

# with open(file_path, 'r') as file:
#     for _ in itertools.islice(file, start_line_number - 1):
#         pass  # This loop will skip lines until we reach the desired starting line

#     for _ in range(lines_to_read):
#         line = next(file, None)
#         if line is None:
#             break  # Reached the end of the file
#         # Process the line as needed
#         print(line)  # Print the line or process it in some other way
